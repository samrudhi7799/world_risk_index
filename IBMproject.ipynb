# %%
import pandas as pd
data=pd.read_csv('C:/Users/ALKA/Desktop/IBM project dataset/world_risk_index.csv')
print(data)
# Out:
#             Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 0          Vanuatu  32.00     56.33          56.81           37.14
# 1            Tonga  29.08     56.04          51.90           28.94
# 2      Philippinen  24.32     45.09          53.93           34.99
# 3        Salomonen  23.51     36.40          64.60           44.11
# 4        Guatemala  20.88     38.42          54.35           35.36
# ...            ...    ...       ...            ...             ...
# 1912       Grenada   1.42      3.13          45.39           24.54
# 1913      Barbados   1.32      3.46          38.26           18.20
# 1914  Saudi Arabia   1.14      2.93          38.96           14.80
# 1915         Malta   0.60      1.65          36.25           15.97
# 1916         Qatar   0.08      0.28          28.18            9.68
#
#       Lack of Coping Capabilities   Lack of Adaptive Capacities  Year  \
# 0                           79.34                         53.96  2011
# ...

# %%
data.head()
# Out:
#         Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 0      Vanuatu  32.00     56.33          56.81           37.14
# 1        Tonga  29.08     56.04          51.90           28.94
# 2  Philippinen  24.32     45.09          53.93           34.99
# 3    Salomonen  23.51     36.40          64.60           44.11
# 4    Guatemala  20.88     38.42          54.35           35.36
#
#    Lack of Coping Capabilities   Lack of Adaptive Capacities  Year  \
# 0                        79.34                         53.96  2011
# 1                        81.80                         44.97  2011
# 2                        82.78                         44.01  2011
# 3                        85.95                         63.74  2011
# 4                        77.83                         49.87  2011
#
#   Exposure Category WRI Category Vulnerability Category  \
# 0         Very High    Very High                   High
# 1         Very High    Very High                 Medium
# ...

# %%
data.tail()
# Out:
#             Region   WRI  Exposure  Vulnerability  Susceptibility  \
# 1912       Grenada  1.42      3.13          45.39           24.54
# 1913      Barbados  1.32      3.46          38.26           18.20
# 1914  Saudi Arabia  1.14      2.93          38.96           14.80
# 1915         Malta  0.60      1.65          36.25           15.97
# 1916         Qatar  0.08      0.28          28.18            9.68
#
#       Lack of Coping Capabilities   Lack of Adaptive Capacities  Year  \
# 1912                        68.82                         42.82  2016
# 1913                        50.29                         46.29  2016
# 1914                        65.01                         37.07  2016
# 1915                        59.33                         33.44  2016
# 1916                        43.94                         30.93  2016
#
#      Exposure Category WRI Category Vulnerability Category  \
# 1912          Very Low     Very Low                 Medium
# ...

# %%
data.describe()
# Out:
#                WRI     Exposure  Vulnerability  Susceptibility  \
# count  1917.000000  1917.000000    1917.000000     1917.000000
# mean      7.551763    15.388336      48.075759       30.739431
# std       5.553257    10.240135      13.835666       15.667030
# min       0.020000     0.050000      14.310000        8.260000
# 25%       3.740000    10.160000      37.040000       17.790000
# 50%       6.520000    12.760000      47.100000       25.400000
# 75%       9.400000    16.450000      60.060000       42.640000
# max      56.710000    99.880000      76.470000       70.830000
#
#        Lack of Coping Capabilities   Lack of Adaptive Capacities         Year
# count                  1917.000000                   1916.000000  1917.000000
# mean                     70.438289                     43.090511  2016.049557
# std                      15.038854                     13.551156     3.182045
# min                      31.590000                     11.160000  2011.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Region                        1917 non-null   object
#  1   WRI                           1917 non-null   float64
#  2   Exposure                      1917 non-null   float64
#  3   Vulnerability                 1917 non-null   float64
#  4   Susceptibility                1917 non-null   float64
#  5   Lack of Coping Capabilities   1917 non-null   float64
#  6    Lack of Adaptive Capacities  1916 non-null   float64
#  7   Year                          1917 non-null   int64
#  8   Exposure Category             1917 non-null   object
#  9   WRI Category                  1916 non-null   object
#  10  Vulnerability Category        1913 non-null   object
#  11  Susceptibility Category       1917 non-null   object
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
data.rename(columns={' Lack of Adaptive Capacities':'Lack of Adaptive Capacities'},inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       1917 non-null   object
#  1   WRI                          1917 non-null   float64
#  2   Exposure                     1917 non-null   float64
#  3   Vulnerability                1917 non-null   float64
#  4   Susceptibility               1917 non-null   float64
#  5   Lack of Coping Capabilities  1917 non-null   float64
#  6   Lack of Adaptive Capacities  1916 non-null   float64
#  7   Year                         1917 non-null   int64
#  8   Exposure Category            1917 non-null   object
#  9   WRI Category                 1916 non-null   object
#  10  Vulnerability Category       1913 non-null   object
#  11  Susceptibility Category      1917 non-null   object
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Region, WRI, Exposure, Vulnerability, Susceptibility, Lack of Coping Capabilities, Lack of Adaptive Capacities, Year, Exposure Category, WRI Category, Vulnerability Category, Susceptibility Category]
# Index: []

# %%
data.isnull().sum()
# Out:
# Region                         0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capabilities    0
# Lack of Adaptive Capacities    1
# Year                           0
# Exposure Category              0
# WRI Category                   1
# Vulnerability Category         4
# Susceptibility Category        0
# dtype: int64

# %%
data['Lack of Adaptive Capacities'].fillna(data['Lack of Adaptive Capacities'].mean(),inplace=True)

# %% [markdown]
# Repalcing the Region name Südkorea to Korea

# %%
data['Region'] = data['Region'].replace('Korea', 'Südkorea')
filtered_data = data[(data['Region'] == 'Südkorea')]

data['Region'] = data['Region'].replace('St.Vincent', '')
filtered_data = data[(data['Region'] == '')]

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Region                         0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capabilities    0
# Lack of Adaptive Capacities    0
# Year                           0
# Exposure Category              0
# WRI Category                   0
# Vulnerability Category         0
# Susceptibility Category        0
# dtype: int64

# %% [markdown]
# Converting data type Object to int

# %%
data.replace({'Exposure Category': {'Very High': 5}}, inplace = True)
data.replace({'Exposure Category': {'High': 4}}, inplace = True)
data.replace({'Exposure Category': {'Medium': 3}}, inplace = True)
data.replace({'Exposure Category': {'Low': 2}}, inplace = True)
data.replace({'Exposure Category': {'Very Low': 1}}, inplace = True)

# %%
data.replace({'Vulnerability Category': {'Very High': 5}}, inplace = True)
data.replace({'Vulnerability Category': {'High': 4}}, inplace = True)
data.replace({'Vulnerability Category': {'Medium': 3}}, inplace = True)
data.replace({'Vulnerability Category': {'Low': 2}}, inplace = True)
data.replace({'Vulnerability Category': {'Very Low': 1}}, inplace = True)

# %%
data.replace({'Susceptibility Category': {'Very High': 5}}, inplace = True)
data.replace({'Susceptibility Category': {'High': 4}}, inplace = True)
data.replace({'Susceptibility Category': {'Medium': 3}}, inplace = True)
data.replace({'Susceptibility Category': {'Low': 2}}, inplace = True)
data.replace({'Susceptibility Category': {'Very Low': 1}}, inplace = True)

# %%
data.replace({'WRI Category': {'Very High': 5}}, inplace = True)
data.replace({'WRI Category': {'High': 4}}, inplace = True)
data.replace({'WRI Category': {'Medium': 3}}, inplace = True)
data.replace({'WRI Category': {'Low': 2}}, inplace = True)
data.replace({'WRI Category': {'Very Low': 1}}, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1912 entries, 0 to 1916
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       1912 non-null   object
#  1   WRI                          1912 non-null   float64
#  2   Exposure                     1912 non-null   float64
#  3   Vulnerability                1912 non-null   float64
#  4   Susceptibility               1912 non-null   float64
#  5   Lack of Coping Capabilities  1912 non-null   float64
#  6   Lack of Adaptive Capacities  1912 non-null   float64
#  7   Year                         1912 non-null   int64
#  8   Exposure Category            1912 non-null   int64
#  9   WRI Category                 1912 non-null   int64
#  10  Vulnerability Category       1912 non-null   int64
#  11  Susceptibility Category      1912 non-null   int64
# dtypes: float64(6), int64(5), object(1)
# ...

# %%
data.describe()
# Out:
#                WRI     Exposure  Vulnerability  Susceptibility  \
# count  1912.000000  1912.000000    1912.000000     1912.000000
# mean      7.555758    15.386182      48.133488       30.757286
# std       5.554435    10.246345      13.792223       15.668835
# min       0.020000     0.050000      20.970000        8.260000
# 25%       3.757500    10.115000      37.100000       17.807500
# 50%       6.525000    12.760000      47.105000       25.415000
# 75%       9.402500    16.450000      60.180000       42.702500
# max      56.710000    99.880000      76.470000       70.830000
#
#        Lack of Coping Capabilities  Lack of Adaptive Capacities         Year  \
# count                  1912.000000                  1912.000000  1912.000000
# mean                     70.508138                    43.135152  2016.042887
# std                      14.977959                    13.511757     3.182770
# min                      35.160000                    11.160000  2011.000000
# ...

# %%
def top6(year):
    return data[data['Year']==year].sort_values(by='WRI')[::-1].head(6)
def bottom6(year):
    return data[data['Year']==year].sort_values(by='WRI').head(6)

# %%
import numpy as np
years= np.sort(data['Year'].unique())[::-1]

# %% [markdown]
# TOP 6 Countries

# %%
import matplotlib.pyplot as plt 
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(24, 12))
plt.subplots_adjust(left=0.2, bottom=0, right=1, top=1, wspace=0.3, hspace=0.5)

for ax,i in zip(axs.ravel(),years):
    ax.bar(top6(i)['Region'],top6(i)['WRI'],)
    ax.set_title(i)
    ax.tick_params(labelrotation=90)
    ax.set_ylim([0,55])
plt.show()

# %% [markdown]
# Bottom 6 Countries

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(24, 12))
plt.subplots_adjust(left=0.2, bottom=0, right=1, top=1, wspace=0.3, hspace=0.5)
for ax,i in zip(axs.ravel(),years):
    ax.bar(bottom6(i)['Region'],bottom6(i)['WRI'],)
    ax.set_title(i)
    ax.tick_params(labelrotation=90)
    ax.set_ylim([0,3])
plt.show()

# %% [markdown]
# Box Plot

# %%
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")
ys = ['WRI','Exposure','Vulnerability','Susceptibility','Lack of Coping Capabilities','Lack of Adaptive Capacities']
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(10, 10))
for ax,i in zip(axs.ravel(),ys):
    sns.boxplot(data[i],ax=ax)
    ax.set_title(i)
plt.show()

# %%
ys = ['WRI','Exposure','Vulnerability','Susceptibility']
fig, ((a,b),(c,d)) = plt.subplots (2, 2, figsize=(12, 10))
for i,t in zip(ys,[a,b,c,d]):
    sns.boxplot(x=i+' Category', y=i,data=data.sort_values(by=i), ax = t)
    t.legend(ncol=3)
    t.set_title(i)
sns.despine()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
data2= data.drop(['Region'],axis=1)

# %%
sns.heatmap(data2.corr(), cmap="Blues",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(data2)
plt.show()

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sb
sb.scatterplot(x = 'Exposure', y = 'WRI', 
		data = data2, s = 100, alpha = 0.3, edgecolor = 'white')

plt.ylabel('WRI', fontsize = 12)
plt.xlabel('Exposure', fontsize = 12)
plt.show()

# %% [markdown]
# Single Linear Regression

# %%
from sklearn.model_selection import train_test_split

X_var = data2[['Exposure']] # independent variable
y_var = data2['WRI'] # dependent variable

X_train, X_test, y_train, y_test = train_test_split(
	X_var, y_var, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
import seaborn as sb
import matplotlib.pyplot as plt
slr_slope = lr.coef_
slr_intercept = lr.intercept_

sb.scatterplot(x = 'Exposure', y = 'WRI', 
		data = data2, s = 150, alpha = 0.3, edgecolor = 'white')
plt.plot(data2['Exposure'], slr_slope*data2['Exposure'] + slr_intercept, 
		color = 'r', linewidth = 3)
plt.title('WRI Prediction', fontsize = 16)
plt.ylabel('WRI', fontsize = 12)
plt.xlabel('Exposure', fontsize = 12)
print(r2_score(y_test, yhat))
plt.show()
# Out:
# 0.8315884408449942

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
X1_var = data2[['Exposure','Vulnerability','Susceptibility','Lack of Coping Capabilities','Lack of Adaptive Capacities',]]
y_var = data2['WRI'] # dependent variable

X_train, X_test, y_train, y_test = train_test_split(
		X1_var, 
		y_var, 
		test_size = 0.3, 
		random_state = 0)

lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

print(r2_score(y_test, yhat))

sb.distplot(yhat, hist = False, color = 'r', label = 'Predicted Values')
sb.distplot(y_test, hist = False, color = 'b', label = 'Actual Values')
plt.title('Actual vs Predicted Values', fontsize = 16)
plt.xlabel('Values', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.legend(loc = 'upper right', fontsize = 13)
print(r2_score(y_test, yhat))
plt.show()
# Out:
# 0.9633605713408239
# 0.9633605713408239
